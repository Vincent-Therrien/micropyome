# %% [markdown]
# # Microbiome Dataset Presentation

# %%
from micropyome.databases import bacteria
from micropyome.utils import file_io

# %%
dst = "./data"
file_io.safe_delete(dst)
bacteria.download("ramirez", dst)
# Out:
# 2024-05-07T00:22:17.511633 > INFO Installing `summary.csv` from bacteria dataset `ramirez`.
# ...
